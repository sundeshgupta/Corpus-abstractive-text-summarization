# %%
# !pip3 install readability
# !pip3 install readability-lxml

from urllib import request, error
from readability.readability import Document
from bs4 import BeautifulSoup
from collections import deque

# %%
url= 'https://ezinearticles.com/?cat=Arts-and-Entertainment:Music&page=1951'
domain = 'https://ezinearticles.com/'

http = 'http://'
https = 'https://'

cnt = 0

visited = {'https://ezinearticles.com/'}

f=open('f1.txt', 'w+')

q = deque()
q.append(url)

while len(q) > 0:
    url = q.popleft()
    req = request.Request(url)
    
    if cnt > 100:
        continue
        
    cnt += 1
    
    if url in visited:
        continue
    
    visited.add(url)
    
    print(url)
    
    
    try: request.urlopen(req)
    except error.URLError as e:
        continue
    
    a = request.urlopen(url).read()
    
    print('here')
    obj = Document(a)
    para = obj.summary()
    title = obj.short_title()
    para = BeautifulSoup(para, 'html.parser').get_text()

    soup = BeautifulSoup(a, 'html.parser')

    l=[]

    for i in soup.find_all('a'):
        l.append(i.get('href'))    
    
    for i in l:
        if i is None:
            continue
        if domain in i:
            q.append(i)
        if (http not in i) and (https not in i):
            q.append(domain + i)
#             print(domain+i)
#         print(i)
    
    s="<url>"+url+'</url>'
    s+='\n'
    s+="<title>"+title+'</title>'
    s+='\n'
    s+="<body>"+para+"</body>"
    f.write(s)

f.close()
# Out:
# https://ezinearticles.com/?cat=Arts-and-Entertainment:Music&page=1951
# here
# https://ezinearticles.com//submit/
# https://ezinearticles.com//about.html
# https://ezinearticles.com//contact.html
# https://ezinearticles.com//?type=experts
# here
# https://ezinearticles.com//
# here
# https://ezinearticles.com//?cat=Arts-and-Entertainment
# here
# https://ezinearticles.com//?type=experts&category=Arts-and-Entertainment:Music
# here
# https://ezinearticles.com//?cat=Arts-and-Entertainment:Animation
# here
# https://ezinearticles.com//?cat=Arts-and-Entertainment:Astrology
# here
# https://ezinearticles.com//?cat=Arts-and-Entertainment:Body-Piercings
# here
# https://ezinearticles.com//?cat=Arts-and-Entertainment:Casino-Gambling
# here
# https://ezinearticles.com//?cat=Arts-and-Entertainment:Filmmaking-and-Film-Editing
# here
# https://ezinearticles.com//?cat=Arts-and-Entertainment:Humanities
# here
# https://ezinearticles.com//?cat=Arts-and-Entertainment:Humor
# ...
